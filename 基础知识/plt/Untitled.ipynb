# %%
import matplotlib.pyplot as plt
plt.ion()
import numpy as np

# %%
fig =plt.figure()
fig.suptitle('No axes on this figure')
# Out:
# Text(0.5, 0.98, 'No axes on this figure')

# %%
fig,ax_1=plt.subplots(2,2)

# %%
plt.ioff()
x=np.linspace(0,2)
y=np.linspace(1,3)
fig,ax=plt.subplots(2,2)
ax[0][0].plot(x,y,'r')
ax[1][1].plot(x,y,'b')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.plot([1,2,3,4],[1,4,9,16],'ro')
#ro是红点
plt.axis([0,5,0,20])
#注意参数是列表
# Out:
# [0, 5, 0, 20]

# %%
ax,=plt.plot([1,2,3,4],[1,4,9,16])
ax.set_agg_filter(DropShadowFilter(4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-19c5e2590d8c> in <module>
#       1 ax,=plt.plot([1,2,3,4],[1,4,9,16])
# ----> 2 ax.set_agg_filter(DropShadowFilter(4))
#
# NameError: name 'DropShadowFilter' is not defined
